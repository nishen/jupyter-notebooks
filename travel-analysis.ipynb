# %% [markdown]
# # Import Libraries

# %%
import re
import json
import numpy
import pandas as pd

# %% [markdown]
# # Prep Data

# %% [markdown]
# #### Read in the raw data

# %%
raw_data = pd.read_json("Data.json")
raw_data.head()
# Out:
#         session_id unix_timestamp  \
# 0  [X061RFWB06K9V]   [1442503708]
# 1  [5AZ2X2A9BHH5U]   [1441353991]
# 2  [SHTB4IYAX4PX6]   [1440843490]
# 3  [JBRB8MZGTX3M4]   [1427268063]
# 4  [YJCMPURC2FL9C]   [1430559067]
#
#                                            cities  \
# 0                        [New York NY, Newark NJ]
# 1  [New York NY, Jersey City NJ, Philadelphia PA]
# 2                                [San Antonio TX]
# 3                                   [Edmonton AB]
# 4                        [Phoenix AZ, Houston TX]
#
#                                                 user
# 0  [[{'user_id': 2024, 'joining_date': '2015-03-2...
# 1  [[{'user_id': 2853, 'joining_date': '2015-03-2...
# 2  [[{'user_id': 10958, 'joining_date': '2015-03-...
# 3  [[{'user_id': 7693, 'joining_date': '2015-03-1...
# 4  [[{'user_id': 7506, 'joining_date': '2015-02-2...

# %% [markdown]
# #### Convert the data we read in into a new Dataframe but extract the JSON structured data into simpler dataframes

# %%
data = pd.DataFrame(raw_data['session_id'].apply(lambda x : x[0]))
data['unix_timestamp'] = raw_data['unix_timestamp'].apply(lambda x: x[0])
data['cities'] = raw_data['cities'].apply(lambda x : re.compile(" *, *").split(x[0].strip()))
data['user_id'] = raw_data['user'].apply(lambda x : x[0][0]['user_id'])
data['joining_date'] = raw_data['user'].apply(lambda x : x[0][0]['joining_date'])
data['country'] = raw_data['user'].apply(lambda x : x[0][0]['country'].strip())
data.head()
# Out:
#       session_id  unix_timestamp  \
# 0  X061RFWB06K9V      1442503708
# 1  5AZ2X2A9BHH5U      1441353991
# 2  SHTB4IYAX4PX6      1440843490
# 3  JBRB8MZGTX3M4      1427268063
# 4  YJCMPURC2FL9C      1430559067
#
#                                            cities  user_id joining_date  \
# 0                        [New York NY, Newark NJ]     2024   2015-03-22
# 1  [New York NY, Jersey City NJ, Philadelphia PA]     2853   2015-03-28
# 2                                [San Antonio TX]    10958   2015-03-06
# 3                                   [Edmonton AB]     7693   2015-03-12
# 4                        [Phoenix AZ, Houston TX]     7506   2015-02-28
#
#   country
# 0      UK
# 1      DE
# 2      UK
# 3      IT
# 4      UK

# %% [markdown]
# #### Cities is now a list, and all other fields have been flattened.
# #### We can split up the cities list into a dataframe with columns for each session.

# %%
cities = data[['session_id', 'cities']]
cities.head()
# Out:
#       session_id                                          cities
# 0  X061RFWB06K9V                        [New York NY, Newark NJ]
# 1  5AZ2X2A9BHH5U  [New York NY, Jersey City NJ, Philadelphia PA]
# 2  SHTB4IYAX4PX6                                [San Antonio TX]
# 3  JBRB8MZGTX3M4                                   [Edmonton AB]
# 4  YJCMPURC2FL9C                        [Phoenix AZ, Houston TX]

# %% [markdown]
# #### We can unpivot the list of cities into a list of sessions + cities

# %%
cities2 = cities['cities'].apply(pd.Series)
a = pd.concat([cities[:], cities2[:]], axis=1)
a.head()
# Out:
#       session_id                                          cities  \
# 0  X061RFWB06K9V                        [New York NY, Newark NJ]
# 1  5AZ2X2A9BHH5U  [New York NY, Jersey City NJ, Philadelphia PA]
# 2  SHTB4IYAX4PX6                                [San Antonio TX]
# 3  JBRB8MZGTX3M4                                   [Edmonton AB]
# 4  YJCMPURC2FL9C                        [Phoenix AZ, Houston TX]
#
#                 0               1                2    3    4    5    6    7  \
# 0     New York NY       Newark NJ              NaN  NaN  NaN  NaN  NaN  NaN
# 1     New York NY  Jersey City NJ  Philadelphia PA  NaN  NaN  NaN  NaN  NaN
# 2  San Antonio TX             NaN              NaN  NaN  NaN  NaN  NaN  NaN
# 3     Edmonton AB             NaN              NaN  NaN  NaN  NaN  NaN  NaN
# 4      Phoenix AZ      Houston TX              NaN  NaN  NaN  NaN  NaN  NaN
#
#      8    9   10
# 0  NaN  NaN  NaN
# 1  NaN  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  NaN  NaN
# 4  NaN  NaN  NaN

# %%
b = a.melt(id_vars=['session_id', 'cities'], value_name='city')
city_session = b.dropna()[['session_id', 'variable', 'city']].sort_values(['session_id', 'variable'])
city_session.head(20)
# Out:
#           session_id variable             city
# 11246  0004TZ56GY6S7        0     San Diego CA
# 31268  0004TZ56GY6S7        1      New York NY
# 19702  004M08GLQ7ZXH        0       Toronto ON
# 5274   007O320DQ7AXT        0      New York NY
# 14910  007UIISVZJOW5        0   San Antonio TX
# 16667  008ZL2D1PLC4O        0      New York NY
# 36689  008ZL2D1PLC4O        1       Chicago IL
# 13779  00C8JBREV4NBU        0  Philadelphia PA
# 2931   00FBBMQ9RPM9N        0       Houston TX
# 2353   00H99K6WLXUXI        0   San Antonio TX
# 22375  00H99K6WLXUXI        1    Fort Worth TX
# 42397  00H99K6WLXUXI        2     Arlington TX
# 8339   00KLXTMMVX344        0      New York NY
# 5940   00KN4XQGM6PU2        0       Toronto ON
# 25962  00KN4XQGM6PU2        1        Oshawa ON
# 7494   00LSZNZZ35S08        0       Toronto ON
# 27516  00LSZNZZ35S08        1       Chicago IL
# 14592  00LXUXAGYB6BU        0      New York NY
# 34614  00LXUXAGYB6BU        1        Boston MA
# 2614   00P3KFQ7US3YQ        0  Philadelphia PA

# %% [markdown]
# # Do Analysis

# %% [markdown]
# We can have a look at the data values. Given there are Canadian cities in the dataset, I would assume that Canada is missing. But hopefully they've provided a list of countries otherwise there are actually about 213 countries missing...

# %%
data['country'].unique()
# Out:
# array(['UK', 'DE', 'IT', 'ES', '', 'US', 'FR'], dtype=object)

# %% [markdown]
# We can have a look at the unique cities in our dataset.

# %%
city_session['city'].unique()
# Out:
# array(['San Diego CA', 'New York NY', 'Toronto ON', 'San Antonio TX',
#        'Chicago IL', 'Philadelphia PA', 'Houston TX', 'Fort Worth TX',
#        'Arlington TX', 'Oshawa ON', 'Boston MA', 'Montreal QC',
#        'Hamilton ON', 'Buffalo NY', 'Saint Catharines Niagara ON',
#        'Los Angeles CA', 'Jersey City NJ', 'Newark NJ', 'Indianapolis IN',
#        'Long Beach CA', 'Vancouver BC', 'Columbus OH', 'Calgary AB',
#        'Seattle WA', 'Portland OR', 'Victoria BC', 'Santa Ana CA',
#        'Dallas TX', 'Kitchener ON', 'Baltimore MD', 'Austin TX',
#        'Phoenix AZ', 'Plano TX', 'Jacksonville FL', 'Detroit MI',
#        'OTTAWA ON', 'Riverside CA', 'Milwaukee WI', 'Madison WI',
#        'Anaheim CA', 'Cincinnati OH', 'Fort Wayne IN', 'Edmonton AB',
#        'Scottsdale AZ', 'Mesa AZ', 'San Jose CA', 'Corpus Christi TX',
#        'Cleveland OH', 'Windsor ON', 'Norfolk VA', 'Lexington KY',
#        'Bakersfield CA', 'Chandler AZ', 'Glendale AZ', 'WASHINGTON DC',
#        'Quebec QC', 'Halifax NS', 'Toledo OH', 'Louisville KY',
#        'Minneapolis MN', 'Saint Paul MN', 'Fresno CA', 'Oklahoma City OK',
#        'London ON', 'Tampa FL', 'Sacramento CA', 'Wichita KS',
#        'Oakland CA', 'San Francisco CA', 'Saint Petersburg FL',
#        'Atlanta GA', 'Charlotte NC', 'Raleigh NC', 'Virginia Beach VA',
#        'Miami FL', 'Hialeah FL', 'Tucson AZ', 'Nashville TN',
#        'Memphis TN', 'Tulsa OK', 'Kansas City MO', 'Lincoln NE',
#        'Chesapeake VA', 'Pittsburgh PA', 'Omaha NE', 'Stockton CA',
#        'Birmingham AL', 'New Orleans LA', 'Greensboro NC'], dtype=object)

# %% [markdown]
# One of the really useful functions is group by... This transforms our list of cities by session into an unpivotted table. We can use this as the basis for our analysis... 1.0's flag where a city was searched ina session.

# %%
stack = c.groupby('session_id')['city'].value_counts().unstack().fillna(0)
stack.head(30)
# Out:
# city           Anaheim CA  Arlington TX  Atlanta GA  Austin TX  \
# session_id
# 0004TZ56GY6S7         0.0           0.0         0.0        0.0
# 004M08GLQ7ZXH         0.0           0.0         0.0        0.0
# 007O320DQ7AXT         0.0           0.0         0.0        0.0
# 007UIISVZJOW5         0.0           0.0         0.0        0.0
# 008ZL2D1PLC4O         0.0           0.0         0.0        0.0
# 00C8JBREV4NBU         0.0           0.0         0.0        0.0
# 00FBBMQ9RPM9N         0.0           0.0         0.0        0.0
# 00H99K6WLXUXI         0.0           1.0         0.0        0.0
# 00KLXTMMVX344         0.0           0.0         0.0        0.0
# 00KN4XQGM6PU2         0.0           0.0         0.0        0.0
# 00LSZNZZ35S08         0.0           0.0         0.0        0.0
# 00LXUXAGYB6BU         0.0           0.0         0.0        0.0
# 00P3KFQ7US3YQ         0.0           0.0         0.0        0.0
# 00SDVGP1YCCUR         0.0           0.0         0.0        0.0
# 00WRM051ZLLWG         0.0           0.0         0.0        0.0
# 00XRQQF81UWEA         0.0           0.0         0.0        0.0
# 013NI3WBUYQ9P         0.0           0.0         0.0        0.0
# 017UBEQK0J64S         0.0           0.0         0.0        0.0
# 01AEZMP136OV8         0.0           0.0         0.0        0.0
# 01AJ7XSGWAIV7         0.0           0.0         0.0        0.0
# 01DD6OKJZ0Y4F         0.0           0.0         0.0        0.0
# 01EUAQY2OYY0Q         0.0           0.0         0.0        0.0
# 01KE8QPBA9ZQ6         0.0           0.0         0.0        0.0
# 01LSJKCZNMLH0       0.0           0.0          0.0                0.0
# 01Q0WTVIU835M       0.0           0.0          0.0                0.0
# 01RX36LY4QVMG       0.0           0.0          0.0                0.0
# 01U1BB1YEVEN6       0.0           0.0          0.0                0.0
# 01WXH1MKISR3C       0.0           0.0          0.0                0.0
# 021MI4G4WHWCR       0.0           1.0          1.0                0.0
# 021QI38H4S5RS       0.0           0.0          0.0                0.0
#
# city           WASHINGTON DC  Wichita KS  Windsor ON
# session_id
# 0004TZ56GY6S7            0.0         0.0         0.0
# 004M08GLQ7ZXH            0.0         0.0         0.0
# 007O320DQ7AXT            0.0         0.0         0.0
# 007UIISVZJOW5            0.0         0.0         0.0
# 008ZL2D1PLC4O            0.0         0.0         0.0
# 00C8JBREV4NBU            0.0         0.0         0.0
# 00FBBMQ9RPM9N            0.0         0.0         0.0
# 00H99K6WLXUXI            0.0         0.0         0.0
# 00KLXTMMVX344            0.0         0.0         0.0
# 00KN4XQGM6PU2            0.0         0.0         0.0
# 00LSZNZZ35S08            0.0         0.0         0.0
# 00LXUXAGYB6BU            0.0         0.0         0.0
# 00P3KFQ7US3YQ            0.0         0.0         0.0
# 00SDVGP1YCCUR            0.0         0.0         0.0
# 00WRM051ZLLWG            0.0         0.0         0.0
# 00XRQQF81UWEA            0.0         0.0         0.0
# 013NI3WBUYQ9P            0.0         0.0         0.0
# 017UBEQK0J64S            0.0         0.0         0.0
# 01AEZMP136OV8            0.0         0.0         0.0
# 01AJ7XSGWAIV7            0.0         0.0         0.0
# 01DD6OKJZ0Y4F            0.0         0.0         0.0
# 01EUAQY2OYY0Q            0.0         0.0         0.0
# 01KE8QPBA9ZQ6            0.0         0.0         0.0
# 01LSJKCZNMLH0            0.0         0.0         0.0
# 01Q0WTVIU835M            0.0         0.0         0.0
# 01RX36LY4QVMG            0.0         0.0         0.0
# 01U1BB1YEVEN6            0.0         0.0         0.0
# 01WXH1MKISR3C            0.0         0.0         0.0
# 021MI4G4WHWCR            0.0         0.0         0.0
# 021QI38H4S5RS            0.0         0.0         0.0
#
# [30 rows x 89 columns]

# %% [markdown]
# Once we have our table above, we can go through each city (lets call this A) and figure out which was the most searched city when also searching for A. From the table, A is always going to be the highest because we are filtering on that city. We need to choose the second highest searched city. That's what we do below:

# %%
# go through each of the cities in our dataset (which is also the columns in our dataset)
for city in stack.columns:
    # for each city, filter the table by sessions which have used our city.
    substack = stack[stack[city] == 1.0]
    # sort by the sum of all cities in our subset.
    sorted_list = numpy.sum(substack, axis=0).sort_values(ascending=False)
    # pick the highest after removing the top result (which is always going to be our initial city, we want 2nd result.)
    highest = sorted_list.iloc[1:].idxmax() if len(sorted_list) > 1 else 'Usually searched alone'
    # print the data... or do whatever you want to do with it...
    print("City [{}]: {}".format(city, highest))
# Out:
# City [Anaheim CA]: Los Angeles CA
# City [Arlington TX]: Dallas TX
# City [Atlanta GA]: Jacksonville FL
# City [Austin TX]: Houston TX
# City [Bakersfield CA]: Los Angeles CA
# City [Baltimore MD]: New York NY
# City [Birmingham AL]: Atlanta GA
# City [Boston MA]: New York NY
# City [Buffalo NY]: Toronto ON
# City [Calgary AB]: Vancouver BC
# City [Chandler AZ]: Phoenix AZ
# City [Charlotte NC]: Jacksonville FL
# City [Chesapeake VA]: New York NY
# City [Chicago IL]: New York NY
# City [Cincinnati OH]: Indianapolis IN
# City [Cleveland OH]: Detroit MI
# City [Columbus OH]: Cincinnati OH
# City [Corpus Christi TX]: San Antonio TX
# City [Dallas TX]: Plano TX
# City [Detroit MI]: Windsor ON
# City [Edmonton AB]: Calgary AB
# City [Fort Wayne IN]: Chicago IL
# City [Fort Worth TX]: Dallas TX
# City [Fresno CA]: San Jose CA
# City [Glendale AZ]: Phoenix AZ
# City [Greensboro NC]: Montreal QC
# City [Halifax NS]: Halifax NS
# City [Hamilton ON]: Toronto ON
# City [Hialeah FL]: Hialeah FL
# City [Houston TX]: New York NY
# City [Indianapolis IN]: Cincinnati OH
# City [Jacksonville FL]: Tampa FL
# City [Jersey City NJ]: New York NY
# City [Kansas City MO]: Fort Worth TX
# City [Kitchener ON]: Toronto ON
# City [Lexington KY]: Indianapolis IN
# City [Lincoln NE]: Madison WI
# City [London ON]: Kitchener ON
# City [Long Beach CA]: Los Angeles CA
# City [Los Angeles CA]: New York NY
# City [Louisville KY]: Indianapolis IN
# City [Madison WI]: Chicago IL
# City [Memphis TN]: Atlanta GA
# City [Mesa AZ]: Phoenix AZ
# City [Miami FL]: Jacksonville FL
# City [Milwaukee WI]: Milwaukee WI
# City [Minneapolis MN]: Chicago IL
# City [Montreal QC]: New York NY
# City [Nashville TN]: Lexington KY
# City [New Orleans LA]: Birmingham AL
# City [New York NY]: Jersey City NJ
# City [Newark NJ]: New York NY
# City [Norfolk VA]: New York NY
# City [OTTAWA ON]: Montreal QC
# City [Oakland CA]: San Jose CA
# City [Oklahoma City OK]: Dallas TX
# City [Omaha NE]: Chicago IL
# City [Oshawa ON]: Toronto ON
# City [Philadelphia PA]: New York NY
# City [Phoenix AZ]: Glendale AZ
# City [Pittsburgh PA]: Toledo OH
# City [Plano TX]: Dallas TX
# City [Portland OR]: Vancouver BC
# City [Quebec QC]: Montreal QC
# City [Raleigh NC]: Chesapeake VA
# City [Riverside CA]: Los Angeles CA
# City [Sacramento CA]: San Jose CA
# City [Saint Catharines-Niagara ON]: Toronto ON
# City [Saint Paul MN]: Chicago IL
# City [Saint Petersburg FL]: Saint Petersburg FL
# City [San Antonio TX]: Houston TX
# City [San Diego CA]: Santa Ana CA
# City [San Francisco CA]: San Jose CA
# City [San Jose CA]: Oakland CA
# City [Santa Ana CA]: Los Angeles CA
# City [Scottsdale AZ]: Phoenix AZ
# City [Seattle WA]: Vancouver BC
# City [Stockton CA]: San Jose CA
# City [Tampa FL]: Tampa FL
# City [Toledo OH]: Detroit MI
# City [Toronto ON]: New York NY
# City [Tucson AZ]: Phoenix AZ
# City [Tulsa OK]: Tulsa OK
# City [Vancouver BC]: Victoria BC
# City [Victoria BC]: Vancouver BC
# City [Virginia Beach VA]: New York NY
# City [WASHINGTON DC]: New York NY
# City [Wichita KS]: Wichita KS
# City [Windsor ON]: Detroit MI
